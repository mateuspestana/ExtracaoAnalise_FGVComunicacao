# %% [markdown]
# # Escola de Comunicação, Mídia e Informação da Fundação Getulio Vargas - FGV Comunicação
#
# ### Curso de Graduação em Comunicação Digital
#
# **Disciplina**: Extração e Análise de Dados
#
# **Professor**: Matheus Cavalcanti Pestana
#
# **Semestre**: 2025.2
#
# **Data**: 24/09/2025
#
# **Nome do aluno(a)**:
#
# #### Primeira Avaliação
#
# ### Instruções
#
# 1. Esta avaliação é individual.
# 2. A avaliação é composta por 6 questões, sendo 1 extra.
# 3. A avaliação deve ser entregue até às 13h00, IMPRETERIVELMENTE, salvo comunicação contrária.
# 4. A avaliação permite consulta à internet e aos materiais de aula, EXCETO a colegas, **gabarito** e modelos grandes de linguagem (ChatGPT, Claude, Gemini e outros). Caso isso ocorra, a prova será zerada.
# 5. É proibido celulares e tablets durante a avaliação, devendo estes serem guardados em mochilas/bolsas e não devem ser usados até a entrega. Caso isso ocorra, a prova será zerada.
# 6. Mantenha o seu celular no modo silencioso.
# 7. Qualquer questão em branco será considerada como resposta errada.
# 8. Preencha o nome do aluno no cabeçalho, abaixo da data, no campo indicado.
# 9. Salve o arquivo em .ipynb no Colab e envie pelo Teams. Verifique se os outputs estão aparecendo no arquivo salvo. (No Colab, vá em Arquivo -> Fazer Download -> **Baixar o .IPYNB**)
# 10. Para cada item de pergunta, escreva a resposta por extenso, **interpretando** os resultados. Essa resposta equivale a 50% da pontuação de cada item.
# 11. Mantenha o Teams fechado durante a prova. Qualquer interferência externa resultará em uma prova zerada.
#
#
# Sites úteis:
#
# - Nosso Github: https://github.com/mateuspestana/ExtracaoAnalise_FGVComunicacao
# - GeeksForGeeks: https://www.geeksforgeeks.org/
# - W3Schools: https://www.w3schools.com/
# - Pandas Documentation: https://pandas.pydata.org/docs/
# - Numpy Documentation: https://numpy.org/doc/
# - FastAPI Documentation: https://fastapi.tiangolo.com/
# - Scikit-learn Documentation: https://scikit-learn.org/stable/api/index.html

# %%
# %%capture
# !pip install fastapi uvicorn

# %% [markdown]
# # Questão 1 - Limpeza de Dados de Texto (0,5 pontos)
#
# Você recebeu uma lista de e-mails de clientes que precisa ser limpa antes de ser processada pelo sistema. Os dados vieram de diferentes fontes e contêm espaços em branco desnecessários e formatação inconsistente.
#
# Considere a seguinte lista de e-mails:
#
# ```python
# emails_clientes = [
#     '   joao.silva@gmail.com   ',
#     '  MARIA.SANTOS@HOTMAIL.COM  ',
#     '     pedro_costa@yahoo.com.br     ',
#     '  ANA.OLIVEIRA@OUTLOOK.COM   ',
#     '    carlos123@empresa.com.br   '
# ]
# ```
#
# **Tarefa:** Usando métodos de manipulação de strings do Python, limpe os e-mails removendo todos os espaços em branco no início e no final de cada e-mail, e converta todos para letras minúsculas.
#
# **Código inicial:**
# ```python
# emails_clientes = [
#     '   joao.silva@gmail.com   ',
#     '  MARIA.SANTOS@HOTMAIL.COM  ',
#     '     pedro_costa@yahoo.com.br     ',
#     '  ANA.OLIVEIRA@OUTLOOK.COM   ',
#     '    carlos123@empresa.com.br   '
# ]
#
# # Seu código aqui - use os métodos adequados para limpar os e-mails
# emails_limpos = []
#
# # Imprima o resultado final
# print("E-mails limpos:")
# for email in emails_limpos:
#     print(email)
# ```
#
# **Resultado esperado:**
# ```
# E-mails limpos:
# joao.silva@gmail.com
# maria.santos@hotmail.com
# pedro_costa@yahoo.com.br
# ana.oliveira@outlook.com
# carlos123@empresa.com.br
# ```
#
# **Dica:** Você precisará usar dois métodos de um tipo de dado em Python. Além disso, o procedimento deve ser realizado usando ou um `for` ou um `list-comprehension`.

# %% [markdown]
# # Questão 2 - API de Biblioteca Digital com FastAPI (2,0 pontos)
#
# Você foi contratado para desenvolver uma API simples para uma biblioteca digital. A API deve gerenciar informações básicas sobre livros e permitir consultas dos usuários.
#
# **Instruções gerais:**
# - Use FastAPI para criar todos os endpoints
# - Todos os endpoints devem retornar dados em formato JSON
# - Não é necessário testar cada endpoint e mostrar o resultado da execução, apenas escrever o código corretamente.
#
# ## Base de dados (NÃO ALTERAR - apenas copiar e colar na célula de código):
#
# ```python
# # Base de dados de livros (lista de dicionários)
# livros_db = [
#     {"id": 1, "titulo": "1984", "autor": "George Orwell", "ano": 1949, "paginas": 328, "genero": "Ficção Científica", "disponivel": True},
#     {"id": 2, "titulo": "Dom Casmurro", "autor": "Machado de Assis", "ano": 1899, "paginas": 256, "genero": "Romance", "disponivel": False},
#     {"id": 3, "titulo": "O Pequeno Príncipe", "autor": "Antoine de Saint-Exupéry", "ano": 1943, "paginas": 96, "genero": "Fábula", "disponivel": True},
#     {"id": 4, "titulo": "Cem Anos de Solidão", "autor": "Gabriel García Márquez", "ano": 1967, "paginas": 417, "genero": "Realismo Mágico", "disponivel": True},
#     {"id": 5, "titulo": "Fahrenheit 451", "autor": "Ray Bradbury", "ano": 1953, "paginas": 249, "genero": "Ficção Científica", "disponivel": False},
#     {"id": 6, "titulo": "O Cortiço", "autor": "Aluísio Azevedo", "ano": 1890, "paginas": 304, "genero": "Naturalismo", "disponivel": True},
#     {"id": 7, "titulo:" "Hypnerotomachia Poliphili", "autor": "Francesco Colonna", "ano": 1499, "paginas": 700, "genero": "Ficção", "disponivel": False}
# ]
# ```
#
# ---
#
# ## Endpoint 1: Rota básica (1,0 ponto)
#
# Crie um endpoint GET na rota `/biblioteca/info` que retorne as seguintes informações da biblioteca:
# - Nome da biblioteca: "Biblioteca Digital FGV Comunicação Rio"
# - Total de livros no acervo
# - Mensagem de boas-vindas: "Bem-vindo à nossa biblioteca digital!"
#
# **Exemplo de retorno esperado:**
# ```json
# {
#     "nome": "Biblioteca Digital FGV Comunicação Rio",
#     "total_livros": 7,
#     "mensagem": "Bem-vindo à nossa biblioteca digital!"
# }
# ```
#
# ---
#
# ## Endpoint 2: Busca por ID (1,0 ponto)
#
# Crie um endpoint GET na rota `/biblioteca/livro/{livro_id}` que:
# - Receba o ID do livro como parâmetro na URL
# - Retorne todas as informações do livro correspondente
# - Caso o livro não seja encontrado, retorne uma mensagem de erro apropriada
#
# **Exemplo de uso:** `/biblioteca/livro/3`
#
# **Exemplo de retorno esperado (livro encontrado):**
# ```json
# {
#     "id": 3,
#     "titulo": "O Pequeno Príncipe",
#     "autor": "Antoine de Saint-Exupéry",
#     "ano": 1943,
#     "paginas": 96,
#     "genero": "Fábula",
#     "disponivel": true
# }
# ```
#
# **Exemplo de retorno esperado (livro não encontrado):**
# ```json
# {
#     "erro": "Livro com ID 10 não encontrado"
# }
# ```
#
# ## Código inicial para começar:
#
# ```python
# from fastapi import FastAPI, Query
# from typing import Optional
#
# app = FastAPI(title="Biblioteca Digital API", version="1.0.0")
#
# # Cole aqui a base de dados de livros
#
# # Seus endpoints aqui...
#
# # Não precisa testar a API!
# ```
#
# **Resposta:** Escreva o código completo da API e teste cada endpoint, mostrando os resultados obtidos.

# %%
 # Resposta (não há necessidade de interpretação)

# %% [markdown]
# # Questão 3 - Análise de Perfis de Influenciadores Digitais com PCA e K-Means (2,0 pontos)
#
# Você foi contratado pela **Viral Marketing Agency** para desenvolver um sistema de categorização de influenciadores digitais. A empresa possui uma base de 180 influenciadores e precisa identificar perfis distintos para otimizar o matching com marcas clientes.
#
# **Instruções gerais:**
# - Use as bibliotecas: `pandas`, `numpy`, `sklearn`, `matplotlib` e `seaborn`
# - Documente suas interpretações para cada resultado
# - Execute cada etapa e mostre os outputs obtidos
# - Mantenha o código organizado e comentado
#
# ## Base de dados (NÃO ALTERAR - apenas executar):
#
# ```python
# # Base de dados de influenciadores digitais
# import pandas as pd
# import numpy as np
#
# np.random.seed(2024)
#
# plataformas = ['Instagram', 'TikTok', 'YouTube', 'Twitter', 'LinkedIn']
# n_influencers_por_plataforma = [50, 45, 35, 30, 20]
#
# lista_plataformas = []
# for plataforma, n in zip(plataformas, n_influencers_por_plataforma):
#     lista_plataformas.extend([plataforma] * n)
#
# total_influencers = len(lista_plataformas)
#
# # Dados realísticos por plataforma
# engajamento_base = {'Instagram': 3.2, 'TikTok': 5.8, 'YouTube': 2.1, 'Twitter': 1.8, 'LinkedIn': 4.5}
# posts_base = {'Instagram': 6, 'TikTok': 12, 'YouTube': 2, 'Twitter': 15, 'LinkedIn': 4}
# autenticidade_base = {'Instagram': 6.5, 'TikTok': 7.8, 'YouTube': 8.2, 'Twitter': 7.0, 'LinkedIn': 8.5}
#
# df_influencers = pd.DataFrame({
#     'PlataformaPrincipal': lista_plataformas,
#     'NomeInfluencer': [f'@creator_{i+1:03d}' for i in range(total_influencers)],
# })
#
# df_influencers['TaxaEngajamento'] = [np.random.normal(engajamento_base[plat], 1.2) for plat in df_influencers['PlataformaPrincipal']]
# df_influencers['PostsPorSemana'] = [np.random.normal(posts_base[plat], 3) for plat in df_influencers['PlataformaPrincipal']]
# df_influencers['PontuacaoAutenticidade'] = [np.random.normal(autenticidade_base[plat], 1.5) for plat in df_influencers['PlataformaPrincipal']]
# df_influencers['DiversidadeConteudo'] = np.random.normal(6.5, 2.0, total_influencers)
# df_influencers['IndiceConversao'] = np.random.normal(25, 15, total_influencers)
#
# # Ajustando valores
# df_influencers['TaxaEngajamento'] = np.clip(df_influencers['TaxaEngajamento'], 0.5, 12.0).round(1)
# df_influencers['PostsPorSemana'] = np.clip(df_influencers['PostsPorSemana'], 1, 25).astype(int)
# df_influencers['DiversidadeConteudo'] = np.clip(df_influencers['DiversidadeConteudo'], 1, 10).round(1)
# df_influencers['PontuacaoAutenticidade'] = np.clip(df_influencers['PontuacaoAutenticidade'], 1, 10).round(1)
# df_influencers['IndiceConversao'] = np.clip(df_influencers['IndiceConversao'], 5, 80).astype(int)
#
# print("-- Base de influenciadores criada!")
# print(f"Total: {len(df_influencers)} influenciadores")
# df_influencers.head()
# ```
#
# ---
#
# ## Etapa 1: Análise Exploratória por Plataforma (0,4 pontos)
#
# Realize uma análise descritiva agrupando os dados por **PlataformaPrincipal** e calcule as médias das seguintes métricas:
# - Taxa de Engajamento (%)
# - Posts por Semana
# - Diversidade de Conteúdo (escala 1-10)
# - Pontuação de Autenticidade (escala 1-10)
# - Índice de Conversão (escala 0-100)
#
# **Interpretação esperada:** Escreva pelo menos 3 insights sobre as diferenças entre plataformas. Ex: "TikTok apresenta a maior taxa de engajamento (X%), o que pode indicar..."
#
# ---
#
# ## Etapa 2: Padronização dos Dados (0,3 pontos)
#
# Padronize as variáveis numéricas usando StandardScaler, preparando os dados para PCA e clustering, e exiba as variáveis antes e depois da padronização.
#
# ---
#
# ## Etapa 3: Aplicação do PCA (0,5 pontos)
#
# Aplique PCA para reduzir a dimensionalidade para 2 componentes principais e interprete os resultados.
#
# **Interpretação esperada:**
# - Qual a variância total explicada pelos 2 componentes? (atributo `.explained_variance_ratio_.sum()`
# - O que cada componente (PC1 e PC2) devem estar explicando?
#
# ---
#
# ## Etapa 4: Clustering com K-Means (0,5 pontos)
#
# Aplique K-Means para identificar 4 grupos de influenciadores e visualize os resultados.
#
# **Análise visual esperada:** Descreva o que você observa no gráfico. Os clusters estão bem separados? Há algum padrão visível?
#
# ---
#
# ## Etapa 5: Caracterização dos Clusters (0,3 pontos)
#
# Analise as características médias de cada cluster e nomeie os arquétipos.
#
# **Nomeação dos arquétipos:** Com base nos dados, sugira nomes para cada cluster. Exemplos:
# - **Cluster 0:** "Content Machines" - Muito volume, diversidade alta
# - **Cluster 1:** "Authentic Voices" - Alta autenticidade, engajamento profundo
# - **Cluster 2:** "Viral Stars" - Alto engajamento, foco em conversão
# - **Cluster 3:** "Steady Creators" - Performance equilibrada
#
# ---
#
# ## Código inicial para começar:
#
# ```python
# # Imports necessários
# import pandas as pd
# import numpy as np
# from sklearn.preprocessing import StandardScaler
# from sklearn.decomposition import PCA
# from sklearn.cluster import KMeans
# import matplotlib.pyplot as plt
# import seaborn as sns
#
# # Configure o estilo dos gráficos
# plt.style.use('default')
# sns.set_palette("viridis")
#
# # Cole aqui a parte da base de dados de influenciadores
# # Seu código aqui...
# ```
#
# **Resposta:** Execute cada etapa SINALIZANDO QUAL A ETAPA ESTÁ SENDO PROCESSADA (dica: faça uma célula diferente por etapa), documente os resultados e forneça suas interpretações sobre os arquétipos de influenciadores identificados. Como uma marca deveria usar essa análise para escolher parceiros?

# %%
# Resposta

# %% [markdown]
# # Questão 4 - Análise Completa de Dados de E-commerce (1,5 pontos)
#
# Você foi contratado para analisar dados de vendas de uma loja online. A empresa precisa de insights sobre o desempenho por categoria, canal de vendas e perfil de clientes para otimizar suas estratégias comerciais.
#
# **Instruções gerais:**
# - Execute cada item sequencialmente, usando os DataFrames gerados nos itens anteriores
# - Documente suas interpretações ao final de cada item
# - Mantenha o código limpo e comentado
#
# ## Base de dados (NÃO ALTERAR - apenas executar):
#
# ```python
# import pandas as pd
# import numpy as np
# from datetime import datetime, timedelta
#
# # Configurando seed para reprodutibilidade
# np.random.seed(42)
#
# # Gerando base de vendas
# n_vendas = 800
# categorias = ['Eletrônicos', 'Roupas', 'Casa', 'Livros', 'Esporte']
# canais = ['Online', 'Loja Física', 'App Mobile', 'Telefone']
# cidades = ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Curitiba', 'Salvador']
#
# df_vendas = pd.DataFrame({
#     'id_venda': range(1, n_vendas + 1),
#     'categoria_produto': np.random.choice(categorias, n_vendas),
#     'canal_venda': np.random.choice(canais, n_vendas),
#     'cidade': np.random.choice(cidades, n_vendas),
#     'qtd_vendida': np.random.randint(1, 10, n_vendas),
#     'preco_unit': np.round(np.random.normal(150, 80, n_vendas), 2),
#     'data_venda': [datetime(2024, 1, 1) + timedelta(days=x) for x in np.random.randint(0, 365, n_vendas)],
#     'satisfacao_cliente': np.round(np.random.normal(4.2, 0.8, n_vendas), 1),
#     'tempo_entrega': np.random.randint(1, 15, n_vendas)
# })
#
# # Ajustando valores para serem realistas
# df_vendas['preco_unit'] = df_vendas['preco_unit'].clip(10, 500)
# df_vendas['satisfacao_cliente'] = df_vendas['satisfacao_cliente'].clip(1.0, 5.0)
#
# # Calculando valor total
# df_vendas['valor_total'] = df_vendas['qtd_vendida'] * df_vendas['preco_unit']
#
# # Introduzindo alguns valores ausentes
# mask_nan = np.random.choice([True, False], size=len(df_vendas), p=[0.03, 0.97])
# df_vendas.loc[mask_nan, 'satisfacao_cliente'] = np.nan
#
# print("📦 Base de vendas criada!")
# print(f"Total de registros: {len(df_vendas)}")
# df_vendas.head()
# ```
#
# ---
#
# ## Item A: Limpeza e Preparação dos Dados (0,3 pontos)
#
# **A1.** Verifique quantos valores ausentes existem na coluna `satisfacao_cliente`.
#
# **A2.** Preencha os valores ausentes de `satisfacao_cliente` com a **mediana** da respectiva categoria de produto.
#
# **A3.** Renomeie as seguintes colunas para o padrão em inglês:
# - `categoria_produto` → `product_category`
# - `canal_venda` → `sales_channel`
# - `qtd_vendida` → `quantity_sold`
# - `preco_unit` → `unit_price`
# - `data_venda` → `sale_date`
# - `satisfacao_cliente` → `customer_satisfaction`
# - `tempo_entrega` → `delivery_time`
#
# ---
#
# ## Item B: Análise por Categoria de Produto (0,6 pontos)
#
# **B1.** Agrupe os dados por `product_category` e calcule:
# - Número total de vendas
# - Valor total vendido
# - Ticket médio (valor médio por venda)
# - Satisfação média do cliente
# - Tempo médio de entrega
#
# **B2.** Ordene o resultado pelo valor total vendido (decrescente).
#
# **B3.** Identifique qual categoria tem a **melhor** e a **pior** satisfação do cliente.
#
# **Interpretação esperada:** Escreva 2-3 insights sobre as diferenças entre categorias.
#
# ---
#
# ## Item C: Análise por Canal e Filtros (0,6 pontos)
#
# **C1.** Crie uma tabela pivot com:
# - Índice: `sales_channel`
# - Colunas: `product_category`
# - Valores: `valor_total` (soma)
# - Preencha valores ausentes com 0
#
# **C2.** Filtre apenas as vendas que atendem a **todos** os critérios:
# - Valor total > R$ 200
# - Satisfação do cliente ≥ 4.0
# - Tempo de entrega ≤ 7 dias
#
# **C3.** Do resultado filtrado, mostre apenas as colunas: `id_venda`, `product_category`, `sales_channel`, `valor_total`, `customer_satisfaction`.
#
# **Interpretação esperada:** Qual canal tem melhor desempenho? Quantas vendas "premium" foram identificadas?
#
# ---
#
# ## Código inicial para começar:
#
# ```python
# import pandas as pd
# import numpy as np
# from datetime import datetime, timedelta
#
# # Cole aqui a base de dados de vendas
# # Seu código aqui...
# ```
#
# **Resposta:** Execute todos os itens sequencialmente e forneça suas interpretações sobre os insights encontrados. Como esses resultados poderiam ajudar na tomada de decisões estratégicas da empresa?

# %%
# Resposta

# %% [markdown]
# # Questão 5 - Sistema de Análise de Notas Escolares (2,0 pontos)
#
# Uma escola precisa automatizar o processo de análise das notas finais dos alunos. Você foi contratado para criar um sistema simples que processe os dados e gere relatórios básicos para a coordenação pedagógica.
#
# **Instruções gerais:**
# - Use apenas Python básico e pandas
# - Execute cada item sequencialmente
# - Documente suas conclusões ao final
#
# ## Base de dados (NÃO ALTERAR - apenas executar):
#
# ```python
# import pandas as pd
# import numpy as np
#
# # Base de notas dos alunos
# np.random.seed(123)
#
# alunos_data = {
#     'nome': ['Ana S.', 'Bruno C.', 'Carla S.', 'Diego O.', 'Elena R.',
#              'Felipe L.', 'Gabriela S.', 'Henrique A.', 'Isabela F.', 'João P.',
#              'Larissa M.', 'Marcos V.', 'Natália C.', 'Otávio R.', 'Patrícia G.',
#              'Rafael B.', 'Sofia R.', 'Thiago N.', 'Vitória C.', 'Wellington T.'],
#
#     'turma': ['A', 'A', 'B', 'A', 'B', 'C', 'B', 'C', 'A', 'B',
#               'C', 'A', 'B', 'C', 'A', 'B', 'C', 'A', 'B', 'C'],
#
#     'matematica': [8.5, 7.2, 9.1, 6.8, 8.9, 7.5, 8.0, 6.3, 9.5, 7.8,
#                    8.2, 6.9, 8.7, 7.1, 9.0, 7.6, 8.4, 6.5, 8.8, 7.3],
#
#     'portugues': [9.0, 6.8, 8.5, 7.2, 9.2, 6.9, 8.1, 7.4, 9.3, 8.0,
#                   7.7, 7.0, 8.9, 6.6, 8.8, 7.5, 8.3, 6.8, 9.1, 7.2],
#
#     'ciencias': [7.8, 8.1, 9.0, 7.5, 8.6, 7.9, 8.3, 7.0, 9.2, 8.4,
#                  8.0, 7.6, 8.5, 7.3, 8.9, 8.2, 8.1, 7.1, 8.7, 7.8],
#
#     'faltas': [2, 8, 1, 12, 3, 15, 4, 18, 0, 6,
#                5, 14, 2, 16, 1, 7, 3, 13, 2, 9]
# }
#
# df_notas = pd.DataFrame(alunos_data)
# print("📚 Base de notas criada!")
# print(f"Total de alunos: {len(df_notas)}")
# print(df_notas.head())
# ```
#
# ---
#
# ## Item A: Cálculo da Média Geral (0,4 pontos)
#
# **A1.** Calcule a média aritmética das três disciplinas (matemática, português, ciências) para cada aluno e adicione uma nova coluna chamada `media_geral`.
#
# **A2.** Identifique qual aluno tem a **maior** média geral e qual tem a **menor** média geral.
#
# ---
#
# ## Item B: Classificação por Status (0,5 pontos)
#
# **B1.** Crie uma nova coluna `status` com as seguintes regras:
# - "Aprovado" se média_geral ≥ 7.0 E faltas ≤ 10
# - "Recuperação" se média_geral ≥ 6.0 E média_geral < 7.0 E faltas ≤ 15
# - "Reprovado" para todos os outros casos
#
# **B2.** Conte quantos alunos estão em cada status.
#
# ---
#
# ## Item C: Análise por Turma (0,6 pontos)
#
# **C1.** Agrupe os dados por `turma` e calcule:
# - Média geral da turma (média das médias individuais)
# - Número total de alunos
# - Número de alunos aprovados
# - Número médio de faltas
#
# **C2.** Identifique qual turma tem o melhor desempenho (maior média geral).
#
# ---
#
# ## Item D: Relatório de Alunos em Risco (0,5 pontos)
#
# **D1.** Filtre e exiba apenas os alunos com status "Reprovado" ou "Recuperação".
#
# **D2.** Para esses alunos, mostre apenas as colunas: `nome`, `turma`, `media_geral`, `faltas`, `status`.
#
# **D3.** Ordene o resultado pela `media_geral` (do menor para o maior).
#
# ---
#
# ## Código inicial para começar:
#
# ```python
# import pandas as pd
# import numpy as np
#
# # Cole aqui a base de dados de notas
# # Seu código aqui...
# ```
#
# **Interpretação final:** Com base nos resultados obtidos, escreva um parágrafo explicando:
# - Qual turma está com melhor desempenho?
# - Quantos alunos precisam de atenção especial (recuperação/reprovação)?
# - Há correlação entre número de faltas e desempenho acadêmico?

# %%
# Resposta

# %% [markdown]
# # Questão 6 – EXTRA – Raspagem (0,5 ponto)
#
# No site oficial de documentação da API do Scikit-learn (https://scikit-learn.org/stable/api/index.html), observe que:
# - Na **barra lateral esquerda**, encontram-se listados os módulos principais (sklearn, sklearn.base, sklearn.calibration, sklearn.cluster, sklearn.compose, ...).
# - Dentro de cada módulo, a documentação exibe as funções e classes disponíveis.
# Exemplo: no módulo `sklearn.tree`, aparecem `DecisionTreeClassifier, DecisionTreeRegressor, ExtraTreeClassifier, ExtraTreeRegressor, export_graphviz, export_text, plot_tree`.
#
# Suponha que desejamos fazer raspagem de dados nesse site para coletar:
#
# 1.	A lista de todos os módulos (apenas os nomes dos módulos);
# 2.	A lista de todas as funções/classes (apenas os nomes das funções/classes).
#
# Sabemos que cada lista pode ser obtida identificando corretamente a tag HTML e a classe CSS utilizadas na página para representar esses elementos. No exemplo:
#
# ```html
# <h1 class='heading-1'>Documentação</h1>
# ```
# a tag é `h1` e a classe é `heading-1`.
#
# Indique, separadamente, qual é a combinação (tag + classe) que retorna somente os módulos e qual retorna somente as funções/classes.
#
# Responda no formato:
#
# ```python
# {'categoria': 'modulos', 'tag': 'XXX', 'classe': 'YYY'}
# {'categoria': 'funcoes/classes', 'tag': 'AAA', 'classe': 'BBB'}
# ```
